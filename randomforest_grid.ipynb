# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
#calling the parameterized function train_test_split 
x_train,x_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'criterion':['poisson','squared_error','friedman_mse','absolute_error'],'max_features':['auto','sqrt','log2'],'n_estimators':[10,100]}

# %%
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.79456642 0.81443486 0.79088993 0.81321009
#         nan        nan 0.79656257 0.8117382  0.79387718 0.81345064
#         nan        nan 0.79347633 0.81042032 0.78647692 0.8133016
#         nan        nan 0.78402689 0.81361184 0.77957899 0.81467235]
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['poisson', 'squared_error',
#                                        'friedman_mse', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print("The Rscore value for best parameter{}:".format(grid.best_params_))
# Out:
# The Rscore value for best parameter{'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001379      0.001083         0.000000        0.000000
# 1        0.001491      0.001437         0.000000        0.000000
# 2        0.068852      0.006522         0.008484        0.002156
# 3        0.791182      0.052797         0.029642        0.003004
# 4        0.093210      0.011046         0.008590        0.004289
# 5        0.766198      0.030307         0.036894        0.007570
# 6        0.002406      0.001638         0.000000        0.000000
# 7        0.001517      0.000447         0.000000        0.000000
# 8        0.074108      0.002502         0.006982        0.000785
# 9        0.723997      0.038583         0.030656        0.001923
# 10       0.073563      0.004354         0.006775        0.002119
# 11       0.702545      0.008184         0.029571        0.003110
# 12       0.001817      0.003238         0.000000        0.000000
# 13       0.002969      0.001988         0.000000        0.000000
# 14       0.080555      0.003924         0.005493        0.001896
# 15       0.721300      0.042800         0.033132        0.007950
# 16       0.076995      0.002939         0.007838        0.002433
# 17       0.697616      0.040337         0.032818        0.007443
# 18       0.001249      0.001941         0.000000        0.000000
# 19       0.001896      0.002700         0.000000        0.000000
# 20       0.210740      0.045167         0.009079        0.004395
# 21       1.682915      0.125704         0.026673        0.010122
# 22       0.212094      0.032469         0.009329        0.003839
# 23       1.844609      0.033271         0.026419        0.004668
#
#    param_criterion param_max_features param_n_estimators  \
# 0          poisson               auto                 10
# 1          poisson               auto                100
# 2          poisson               sqrt                 10
# 3          poisson               sqrt                100
# 4          poisson               log2                 10
# 5          poisson               log2                100
# 6    squared_error               auto                 10
# 7    squared_error               auto                100
# 8    squared_error               sqrt                 10
# 9    squared_error               sqrt                100
# 10   squared_error               log2                 10
# 11   squared_error               log2                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               sqrt                 10
# 15    friedman_mse               sqrt                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
# 18  absolute_error               auto                 10
# 19  absolute_error               auto                100
# 20  absolute_error               sqrt                 10
# 21  absolute_error               sqrt                100
# 22  absolute_error               log2                 10
# 23  absolute_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 1   {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 2   {'criterion': 'poisson', 'max_features': 'sqrt...           0.850483
# 3   {'criterion': 'poisson', 'max_features': 'sqrt...           0.864057
# 4   {'criterion': 'poisson', 'max_features': 'log2...           0.836108
# 5   {'criterion': 'poisson', 'max_features': 'log2...           0.862868
# 6   {'criterion': 'squared_error', 'max_features':...                NaN
# 7   {'criterion': 'squared_error', 'max_features':...                NaN
# 8   {'criterion': 'squared_error', 'max_features':...           0.835748
# 9   {'criterion': 'squared_error', 'max_features':...           0.863208
# 10  {'criterion': 'squared_error', 'max_features':...           0.844516
# 11  {'criterion': 'squared_error', 'max_features':...           0.869302
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.842439
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.863183
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.850316
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.868258
# 18  {'criterion': 'absolute_error', 'max_features'...                NaN
# 19  {'criterion': 'absolute_error', 'max_features'...                NaN
# 20  {'criterion': 'absolute_error', 'max_features'...           0.804542
# 21  {'criterion': 'absolute_error', 'max_features'...           0.863514
# 22  {'criterion': 'absolute_error', 'max_features'...           0.849295
# 23  {'criterion': 'absolute_error', 'max_features'...           0.861080
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.790779           0.774706           0.803127
# 3            0.793999           0.811856           0.832500
# 4            0.798617           0.794700           0.775721
# 5            0.790703           0.812483           0.828238
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.782205           0.781955           0.816332
# 9            0.797429           0.806006           0.826891
# 10           0.784386           0.784214           0.799363
# 11           0.795073           0.808399           0.825385
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.779847           0.785983           0.799138
# 15           0.787683           0.811159           0.825978
# 16           0.775186           0.771235           0.795374
# 17           0.793307           0.808884           0.827882
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.768214           0.792789           0.792334
# 21           0.796330           0.808554           0.824867
# 22           0.751120           0.772344           0.787610
# 23           0.795516           0.814950           0.828411
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.753737         0.794566        0.032483               10
# 3            0.769763         0.814435        0.032275                2
# 4            0.749303         0.790890        0.028560               13
# 5            0.771759         0.813210        0.031360                6
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.766572         0.796563        0.025477                9
# 9            0.765157         0.811738        0.032515                7
# 10           0.756907         0.793877        0.028791               11
# 11           0.769094         0.813451        0.033444                4
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.759974         0.793476        0.027545               12
# 15           0.764099         0.810420        0.033732                8
# 16           0.740274         0.786477        0.036467               14
# 17           0.768178         0.813302        0.033729                5
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.762255         0.784027        0.016067               15
# 21           0.774794         0.813612        0.029826                3
# 22           0.737525         0.779579        0.038873               16
# 23           0.773404         0.814672        0.029707                1

# %%
age_input=float(input('Age'))
bmi_input=float(input('bmi'))
Children_input=int(input('children'))
sex_input=int(input('sex'))
smoker_input=int(input('smoker'))
# Out:
# Age 5
# bmi 56
# children 4
# sex 1
# smoker 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,Children_input,sex_input,smoker_input]])
Future_Prediction
# Out:
# array([17891.9869515])
